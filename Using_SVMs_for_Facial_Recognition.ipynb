# %% [markdown]
# <a href="https://colab.research.google.com/github/dustinober1/Using-SVMs-for-Facial-Recognition/blob/main/Using_SVMs_for_Facial_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using SVMs for Facial Recognition

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_lfw_people
 
faces = fetch_lfw_people(min_faces_per_person=100, slice_=None)
faces.images = faces.images[:, 35:97, 39:86]
faces.data = faces.images.reshape(faces.images.shape[0], faces.images.shape[1] *
                                  faces.images.shape[2])
print(faces.target_names)
print(faces.images.shape)
# Out:
# ['Colin Powell' 'Donald Rumsfeld' 'George W Bush' 'Gerhard Schroeder'
#  'Tony Blair']
# (1140, 62, 47)

# %% [markdown]
# In total, 1,140 facial images were loaded. Each image measures 47 × 62 pixels for a total of 2,914 pixels per image. That means the dataset contains 2,914 features. Use the following code to show the first 24 images in the dataset and the people to whom the faces belong:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
 
fig, ax = plt.subplots(3, 8, figsize=(18, 10))
for i, axi in enumerate(ax.flat):
    axi.imshow(faces.images[i], cmap='gist_gray')
    axi.set(xticks=[], yticks=[], xlabel=faces.target_names[faces.target[i]])

# %% [markdown]
# Check the balance in the dataset by generating a histogram showing how many facial images were imported for each person:

# %%
import seaborn as sns
sns.set()

from collections import Counter
counts = Counter(faces.target)
names = {}
 
for key in counts.keys():
    names[faces.target_names[key]] = counts[key]
 
df = pd.DataFrame.from_dict(names, orient='index')
df.plot(kind='bar')

# %% [markdown]
# The output reveals that there are far more images of George W. Bush than of anyone else in the dataset.
#
# Classification models are best trained with balanced datasets. Use the following code to reduce the dataset to 100 images of each person:

# %%
mask = np.zeros(faces.target.shape, dtype=bool)
 
for target in np.unique(faces.target):
    mask[np.where(faces.target == target)[0][:100]] = 1
     
x = faces.data[mask]
y = faces.target[mask]
x.shape
# Out:
# (500, 2914)

# %% [markdown]
# Note that x contains 500 facial images and y contains the labels that go with them: 0 for Colin Powell, 1 for Donald Rumsfeld, and so on. Now let’s see if an SVM can make sense of the data. We’ll train three different models: one that uses a linear kernel, one that uses a polynomial kernel, and one that uses an RBF kernel. In each case, we’ll use GridSearchCV to optimize hyperparameters. Start with a linear model and four different values of C:

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
 
svc = SVC(kernel='linear')
 
grid = {
    'C': [0.1, 1, 10, 100]
}
 
grid_search = GridSearchCV(estimator=svc, param_grid=grid, cv=5, verbose=2)
grid_search.fit(x, y) # Train the model with different parameters
grid_search.best_score_
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] END ..............................................C=0.1; total time=   0.4s
# [CV] END ..............................................C=0.1; total time=   0.3s
# [CV] END ..............................................C=0.1; total time=   0.3s
# [CV] END ..............................................C=0.1; total time=   0.6s
# [CV] END ..............................................C=0.1; total time=   0.4s
# [CV] END ................................................C=1; total time=   0.2s
# [CV] END ................................................C=1; total time=   0.2s
# [CV] END ................................................C=1; total time=   0.3s
# [CV] END ................................................C=1; total time=   0.4s
# [CV] END ................................................C=1; total time=   0.3s
# [CV] END ...............................................C=10; total time=   0.2s
# [CV] END ...............................................C=10; total time=   0.1s
# [CV] END ...............................................C=10; total time=   0.2s
# [CV] END ...............................................C=10; total time=   0.2s
# [CV] END ...............................................C=10; total time=   0.1s
# [CV] END ..............................................C=100; total time=   0.1s
# [CV] END ..............................................C=100; total time=   0.1s
# [CV] END ..............................................C=100; total time=   0.1s
# [CV] END ..............................................C=100; total time=   0.1s
# [CV] END ..............................................C=100; total time=   0.1s
# 0.8400000000000001

# %% [markdown]
# This model achieves a cross-validated accuracy of 84.2%. It’s possible that accuracy can be improved by standardizing the image data. Run the same grid search again, but this time use StandardScaler to apply unit variance to all the pixel values:

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
 
scaler = StandardScaler()
svc = SVC(kernel='linear')
pipe = make_pipeline(scaler, svc)
 
grid = {
    'svc__C': [0.1, 1, 10, 100]
}
 
grid_search = GridSearchCV(estimator=pipe, param_grid=grid, cv=5, verbose=2)
grid_search.fit(x, y)
grid_search.best_score_
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] END .........................................svc__C=0.1; total time=   0.4s
# [CV] END .........................................svc__C=0.1; total time=   0.4s
# [CV] END .........................................svc__C=0.1; total time=   0.4s
# [CV] END .........................................svc__C=0.1; total time=   0.3s
# [CV] END .........................................svc__C=0.1; total time=   0.2s
# [CV] END ...........................................svc__C=1; total time=   0.2s
# [CV] END ...........................................svc__C=1; total time=   0.2s
# [CV] END ...........................................svc__C=1; total time=   0.2s
# [CV] END ...........................................svc__C=1; total time=   0.2s
# [CV] END ...........................................svc__C=1; total time=   0.1s
# [CV] END ..........................................svc__C=10; total time=   0.2s
# [CV] END ..........................................svc__C=10; total time=   0.1s
# [CV] END ..........................................svc__C=10; total time=   0.1s
# [CV] END ..........................................svc__C=10; total time=   0.2s
# [CV] END ..........................................svc__C=10; total time=   0.1s
# [CV] END .........................................svc__C=100; total time=   0.2s
# [CV] END .........................................svc__C=100; total time=   0.1s
# [CV] END .........................................svc__C=100; total time=   0.1s
# [CV] END .........................................svc__C=100; total time=   0.1s
# [CV] END .........................................svc__C=100; total time=   0.1s
# 0.8560000000000001

# %% [markdown]
# Standardizing the data produced an incremental improvement in accuracy. What value of C produced that accuracy?

# %%
grid_search.best_params_
# Out:
# {'svc__C': 0.1}

# %% [markdown]
# Is it possible that a polynomial kernel could outperform a linear kernel? There’s an easy way to find out. Note the introduction of the gamma and degree parameters to the parameter grid. These parameters, along with C, can greatly influence a polynomial kernel’s ability to fit to the training data:

# %%
scaler = StandardScaler()
svc = SVC(kernel='poly')
pipe = make_pipeline(scaler, svc)
 
grid = {
    'svc__C': [0.1, 1, 10, 100],
    'svc__gamma': [0.01, 0.25, 0.5, 0.75, 1],
    'svc__degree': [1, 2, 3, 4, 5]
}
 
grid_search = GridSearchCV(estimator=pipe, param_grid=grid, cv=5, verbose=2)
grid_search.fit(x, y) # Train the model with different parameter combinations
grid_search.best_score_
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END .........svc__C=0.1, svc__degree=1, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=1, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=1, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=1, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=1, svc__gamma=0.01; total time=   0.1s
# [CV] END .........svc__C=0.1, svc__degree=1, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END .........svc__C=0.1, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END .........svc__C=0.1, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END .........svc__C=0.1, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END ..........svc__C=0.1, svc__degree=1, svc__gamma=0.5; total time=   0.1s
# [CV] END ..........svc__C=0.1, svc__degree=1, svc__gamma=0.5; total time=   0.1s
# [CV] END ..........svc__C=0.1, svc__degree=1, svc__gamma=0.5; total time=   0.1s
# [CV] END ..........svc__C=0.1, svc__degree=1, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=1, svc__gamma=0.5; total time=   0.1s
# [CV] END .........svc__C=0.1, svc__degree=1, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=1, svc__gamma=0.75; total time=   0.1s
# [CV] END .........svc__C=0.1, svc__degree=1, svc__gamma=0.75; total time=   0.1s
# [CV] END .........svc__C=0.1, svc__degree=1, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=1, svc__gamma=0.75; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=1, svc__gamma=1; total time=   0.1s
# [CV] END ............svc__C=0.1, svc__degree=1, svc__gamma=1; total time=   0.1s
# [CV] END ............svc__C=0.1, svc__degree=1, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=1, svc__gamma=1; total time=   0.1s
# [CV] END ............svc__C=0.1, svc__degree=1, svc__gamma=1; total time=   0.1s
# [CV] END .........svc__C=0.1, svc__degree=2, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=2, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=2, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=2, svc__gamma=0.01; total time=   0.3s
# [CV] END .........svc__C=0.1, svc__degree=2, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=2, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=2, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=2, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=2, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=2, svc__gamma=0.5; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=2, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=2, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=2, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=2, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=2, svc__gamma=0.75; total time=   0.3s
# [CV] END ............svc__C=0.1, svc__degree=2, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=2, svc__gamma=1; total time=   0.3s
# [CV] END ............svc__C=0.1, svc__degree=2, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=2, svc__gamma=1; total time=   0.3s
# [CV] END ............svc__C=0.1, svc__degree=2, svc__gamma=1; total time=   0.3s
# [CV] END .........svc__C=0.1, svc__degree=3, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=3, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=3, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=3, svc__gamma=0.01; total time=   0.3s
# [CV] END .........svc__C=0.1, svc__degree=3, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=3, svc__gamma=0.25; total time=   0.3s
# [CV] END .........svc__C=0.1, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=3, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=3, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=3, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=3, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=3, svc__gamma=0.5; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=3, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=3, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=3, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=3, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=3, svc__gamma=0.75; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=4, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=4, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=4, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=4, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=4, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=4, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=4, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=4, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=4, svc__gamma=0.5; total time=   0.3s
# [CV] END ..........svc__C=0.1, svc__degree=4, svc__gamma=0.5; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=4, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=4, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=4, svc__gamma=1; total time=   0.3s
# [CV] END ............svc__C=0.1, svc__degree=4, svc__gamma=1; total time=   0.3s
# [CV] END ............svc__C=0.1, svc__degree=4, svc__gamma=1; total time=   0.3s
# [CV] END .........svc__C=0.1, svc__degree=5, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=5, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=5, svc__gamma=0.01; total time=   0.3s
# [CV] END .........svc__C=0.1, svc__degree=5, svc__gamma=0.01; total time=   0.3s
# [CV] END .........svc__C=0.1, svc__degree=5, svc__gamma=0.01; total time=   0.3s
# [CV] END .........svc__C=0.1, svc__degree=5, svc__gamma=0.25; total time=   0.3s
# [CV] END .........svc__C=0.1, svc__degree=5, svc__gamma=0.25; total time=   0.3s
# [CV] END .........svc__C=0.1, svc__degree=5, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=5, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=5, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=0.1, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=0.1, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=5, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=5, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=5, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=5, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=0.1, svc__degree=5, svc__gamma=1; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=1, svc__gamma=0.01; total time=   0.1s
# [CV] END ...........svc__C=1, svc__degree=1, svc__gamma=0.01; total time=   0.1s
# [CV] END ...........svc__C=1, svc__degree=1, svc__gamma=0.01; total time=   0.1s
# [CV] END ...........svc__C=1, svc__degree=1, svc__gamma=0.01; total time=   0.1s
# [CV] END ...........svc__C=1, svc__degree=1, svc__gamma=0.01; total time=   0.1s
# [CV] END ...........svc__C=1, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END ...........svc__C=1, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END ...........svc__C=1, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END ...........svc__C=1, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END ...........svc__C=1, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END ............svc__C=1, svc__degree=1, svc__gamma=0.5; total time=   0.1s
# [CV] END ............svc__C=1, svc__degree=1, svc__gamma=0.5; total time=   0.1s
# [CV] END ............svc__C=1, svc__degree=1, svc__gamma=0.5; total time=   0.1s
# [CV] END ............svc__C=1, svc__degree=1, svc__gamma=0.5; total time=   0.2s
# [CV] END ............svc__C=1, svc__degree=1, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=1, svc__gamma=0.75; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=1, svc__gamma=0.75; total time=   0.1s
# [CV] END ...........svc__C=1, svc__degree=1, svc__gamma=0.75; total time=   0.1s
# [CV] END ...........svc__C=1, svc__degree=1, svc__gamma=0.75; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=1, svc__gamma=0.75; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=1, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=1, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=1, svc__gamma=1; total time=   0.1s
# [CV] END ..............svc__C=1, svc__degree=1, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=1, svc__gamma=1; total time=   0.1s
# [CV] END ...........svc__C=1, svc__degree=2, svc__gamma=0.01; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=2, svc__gamma=0.01; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=2, svc__gamma=0.01; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=2, svc__gamma=0.01; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=2, svc__gamma=0.01; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=2, svc__gamma=0.25; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=2, svc__gamma=0.25; total time=   0.6s
# [CV] END ............svc__C=1, svc__degree=2, svc__gamma=0.5; total time=   0.4s
# [CV] END ............svc__C=1, svc__degree=2, svc__gamma=0.5; total time=   0.3s
# [CV] END ............svc__C=1, svc__degree=2, svc__gamma=0.5; total time=   0.5s
# [CV] END ............svc__C=1, svc__degree=2, svc__gamma=0.5; total time=   0.6s
# [CV] END ............svc__C=1, svc__degree=2, svc__gamma=0.5; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=2, svc__gamma=0.75; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=2, svc__gamma=0.75; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=2, svc__gamma=0.75; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=2, svc__gamma=0.75; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=2, svc__gamma=0.75; total time=   0.3s
# [CV] END ..............svc__C=1, svc__degree=2, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=2, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=2, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=2, svc__gamma=1; total time=   0.3s
# [CV] END ..............svc__C=1, svc__degree=2, svc__gamma=1; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=3, svc__gamma=0.01; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=3, svc__gamma=0.01; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=3, svc__gamma=0.01; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=3, svc__gamma=0.01; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=3, svc__gamma=0.01; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=3, svc__gamma=0.25; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END ............svc__C=1, svc__degree=3, svc__gamma=0.5; total time=   0.2s
# [CV] END ............svc__C=1, svc__degree=3, svc__gamma=0.5; total time=   0.2s
# [CV] END ............svc__C=1, svc__degree=3, svc__gamma=0.5; total time=   0.4s
# [CV] END ............svc__C=1, svc__degree=3, svc__gamma=0.5; total time=   0.4s
# [CV] END ............svc__C=1, svc__degree=3, svc__gamma=0.5; total time=   0.4s
# [CV] END ...........svc__C=1, svc__degree=3, svc__gamma=0.75; total time=   0.4s
# [CV] END ...........svc__C=1, svc__degree=3, svc__gamma=0.75; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=3, svc__gamma=0.75; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=3, svc__gamma=0.75; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=3, svc__gamma=0.75; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=4, svc__gamma=0.01; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=4, svc__gamma=0.25; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=4, svc__gamma=0.25; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=4, svc__gamma=0.25; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=4, svc__gamma=0.25; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=4, svc__gamma=0.25; total time=   0.3s
# [CV] END ............svc__C=1, svc__degree=4, svc__gamma=0.5; total time=   0.3s
# [CV] END ............svc__C=1, svc__degree=4, svc__gamma=0.5; total time=   0.3s
# [CV] END ............svc__C=1, svc__degree=4, svc__gamma=0.5; total time=   0.3s
# [CV] END ............svc__C=1, svc__degree=4, svc__gamma=0.5; total time=   0.3s
# [CV] END ............svc__C=1, svc__degree=4, svc__gamma=0.5; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=4, svc__gamma=0.75; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=4, svc__gamma=0.75; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=4, svc__gamma=0.75; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=4, svc__gamma=0.75; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=4, svc__gamma=1; total time=   0.3s
# [CV] END ..............svc__C=1, svc__degree=4, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=4, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=4, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=4, svc__gamma=1; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=5, svc__gamma=0.01; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=5, svc__gamma=0.01; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=5, svc__gamma=0.01; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=5, svc__gamma=0.01; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=5, svc__gamma=0.01; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=5, svc__gamma=0.25; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=5, svc__gamma=0.25; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=5, svc__gamma=0.25; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=5, svc__gamma=0.25; total time=   0.3s
# [CV] END ...........svc__C=1, svc__degree=5, svc__gamma=0.25; total time=   0.2s
# [CV] END ............svc__C=1, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ............svc__C=1, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ............svc__C=1, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ............svc__C=1, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ............svc__C=1, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END ...........svc__C=1, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=5, svc__gamma=1; total time=   0.3s
# [CV] END ..............svc__C=1, svc__degree=5, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=5, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=5, svc__gamma=1; total time=   0.2s
# [CV] END ..............svc__C=1, svc__degree=5, svc__gamma=1; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=1, svc__gamma=0.01; total time=   0.1s
# [CV] END ..........svc__C=10, svc__degree=1, svc__gamma=0.01; total time=   0.1s
# [CV] END ..........svc__C=10, svc__degree=1, svc__gamma=0.01; total time=   0.1s
# [CV] END ..........svc__C=10, svc__degree=1, svc__gamma=0.01; total time=   0.1s
# [CV] END ..........svc__C=10, svc__degree=1, svc__gamma=0.01; total time=   0.1s
# [CV] END ..........svc__C=10, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END ..........svc__C=10, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END ..........svc__C=10, svc__degree=1, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=1, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END ...........svc__C=10, svc__degree=1, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=1, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=1, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=1, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=1, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=1, svc__gamma=0.75; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=1, svc__gamma=0.75; total time=   0.1s
# [CV] END ..........svc__C=10, svc__degree=1, svc__gamma=0.75; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=1, svc__gamma=0.75; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=1, svc__gamma=0.75; total time=   0.2s
# [CV] END .............svc__C=10, svc__degree=1, svc__gamma=1; total time=   0.2s
# [CV] END .............svc__C=10, svc__degree=1, svc__gamma=1; total time=   0.2s
# [CV] END .............svc__C=10, svc__degree=1, svc__gamma=1; total time=   0.2s
# [CV] END .............svc__C=10, svc__degree=1, svc__gamma=1; total time=   0.2s
# [CV] END .............svc__C=10, svc__degree=1, svc__gamma=1; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=2, svc__gamma=0.01; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=2, svc__gamma=0.01; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=2, svc__gamma=0.01; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=2, svc__gamma=0.01; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=2, svc__gamma=0.01; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=2, svc__gamma=0.25; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=2, svc__gamma=0.25; total time=   0.3s
# [CV] END ...........svc__C=10, svc__degree=2, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=2, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=2, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=2, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=2, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=2, svc__gamma=0.75; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=2, svc__gamma=0.75; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=2, svc__gamma=0.75; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=2, svc__gamma=0.75; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=2, svc__gamma=0.75; total time=   0.3s
# [CV] END .............svc__C=10, svc__degree=2, svc__gamma=1; total time=   0.3s
# [CV] END .............svc__C=10, svc__degree=2, svc__gamma=1; total time=   0.3s
# [CV] END .............svc__C=10, svc__degree=2, svc__gamma=1; total time=   0.3s
# [CV] END .............svc__C=10, svc__degree=2, svc__gamma=1; total time=   0.4s
# [CV] END .............svc__C=10, svc__degree=2, svc__gamma=1; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=3, svc__gamma=0.01; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=3, svc__gamma=0.01; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=3, svc__gamma=0.01; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=3, svc__gamma=0.01; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=3, svc__gamma=0.01; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=3, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=3, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=3, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=3, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=3, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=3, svc__gamma=0.75; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=3, svc__gamma=0.75; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=3, svc__gamma=0.75; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=3, svc__gamma=0.75; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=3, svc__gamma=0.75; total time=   0.2s
# [CV] END .............svc__C=10, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END .............svc__C=10, svc__degree=3, svc__gamma=1; total time=   0.4s
# [CV] END .............svc__C=10, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END .............svc__C=10, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END .............svc__C=10, svc__degree=3, svc__gamma=1; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=4, svc__gamma=0.01; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=4, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=4, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=4, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=4, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=4, svc__gamma=0.25; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=4, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=4, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=4, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=4, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=4, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END .............svc__C=10, svc__degree=4, svc__gamma=1; total time=   0.2s
# [CV] END .............svc__C=10, svc__degree=4, svc__gamma=1; total time=   0.3s
# [CV] END .............svc__C=10, svc__degree=4, svc__gamma=1; total time=   0.3s
# [CV] END .............svc__C=10, svc__degree=4, svc__gamma=1; total time=   0.3s
# [CV] END .............svc__C=10, svc__degree=4, svc__gamma=1; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=5, svc__gamma=0.01; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=5, svc__gamma=0.01; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=5, svc__gamma=0.01; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=5, svc__gamma=0.01; total time=   0.4s
# [CV] END ..........svc__C=10, svc__degree=5, svc__gamma=0.01; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=5, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=5, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=5, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=5, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=5, svc__gamma=0.25; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ...........svc__C=10, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END ..........svc__C=10, svc__degree=5, svc__gamma=0.75; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=5, svc__gamma=0.75; total time=   0.3s
# [CV] END ..........svc__C=10, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END .............svc__C=10, svc__degree=5, svc__gamma=1; total time=   0.3s
# [CV] END .............svc__C=10, svc__degree=5, svc__gamma=1; total time=   0.2s
# [CV] END .............svc__C=10, svc__degree=5, svc__gamma=1; total time=   0.2s
# [CV] END .............svc__C=10, svc__degree=5, svc__gamma=1; total time=   0.2s
# [CV] END .............svc__C=10, svc__degree=5, svc__gamma=1; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=1, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=1, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=1, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=1, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=1, svc__gamma=0.01; total time=   0.1s
# [CV] END .........svc__C=100, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END .........svc__C=100, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END .........svc__C=100, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END .........svc__C=100, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END .........svc__C=100, svc__degree=1, svc__gamma=0.25; total time=   0.1s
# [CV] END ..........svc__C=100, svc__degree=1, svc__gamma=0.5; total time=   0.1s
# [CV] END ..........svc__C=100, svc__degree=1, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=1, svc__gamma=0.5; total time=   0.1s
# [CV] END ..........svc__C=100, svc__degree=1, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=1, svc__gamma=0.5; total time=   0.1s
# [CV] END .........svc__C=100, svc__degree=1, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=1, svc__gamma=0.75; total time=   0.1s
# [CV] END .........svc__C=100, svc__degree=1, svc__gamma=0.75; total time=   0.1s
# [CV] END .........svc__C=100, svc__degree=1, svc__gamma=0.75; total time=   0.1s
# [CV] END .........svc__C=100, svc__degree=1, svc__gamma=0.75; total time=   0.1s
# [CV] END ............svc__C=100, svc__degree=1, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=1, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=1, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=1, svc__gamma=1; total time=   0.1s
# [CV] END ............svc__C=100, svc__degree=1, svc__gamma=1; total time=   0.1s
# [CV] END .........svc__C=100, svc__degree=2, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=2, svc__gamma=0.01; total time=   0.3s
# [CV] END .........svc__C=100, svc__degree=2, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=2, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=2, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=2, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=2, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=2, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=2, svc__gamma=0.5; total time=   0.3s
# [CV] END ..........svc__C=100, svc__degree=2, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=2, svc__gamma=0.5; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=2, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=2, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=2, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=2, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=2, svc__gamma=0.75; total time=   0.3s
# [CV] END ............svc__C=100, svc__degree=2, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=2, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=2, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=2, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=2, svc__gamma=1; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=3, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=3, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=3, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=3, svc__gamma=0.01; total time=   0.3s
# [CV] END .........svc__C=100, svc__degree=3, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=3, svc__gamma=0.25; total time=   0.3s
# [CV] END .........svc__C=100, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=3, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=3, svc__gamma=0.5; total time=   0.3s
# [CV] END ..........svc__C=100, svc__degree=3, svc__gamma=0.5; total time=   0.3s
# [CV] END ..........svc__C=100, svc__degree=3, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=3, svc__gamma=0.5; total time=   0.3s
# [CV] END ..........svc__C=100, svc__degree=3, svc__gamma=0.5; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=3, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=3, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=3, svc__gamma=0.75; total time=   0.3s
# [CV] END .........svc__C=100, svc__degree=3, svc__gamma=0.75; total time=   0.3s
# [CV] END .........svc__C=100, svc__degree=3, svc__gamma=0.75; total time=   0.3s
# [CV] END ............svc__C=100, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=3, svc__gamma=1; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=4, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=4, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=4, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=4, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=4, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=4, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=4, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=4, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=4, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=4, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=4, svc__gamma=0.5; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=4, svc__gamma=0.75; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=4, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=4, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=4, svc__gamma=1; total time=   0.3s
# [CV] END ............svc__C=100, svc__degree=4, svc__gamma=1; total time=   0.3s
# [CV] END ............svc__C=100, svc__degree=4, svc__gamma=1; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=5, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=5, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=5, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=5, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=5, svc__gamma=0.01; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=5, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=5, svc__gamma=0.25; total time=   0.3s
# [CV] END .........svc__C=100, svc__degree=5, svc__gamma=0.25; total time=   0.3s
# [CV] END .........svc__C=100, svc__degree=5, svc__gamma=0.25; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=5, svc__gamma=0.25; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=5, svc__gamma=0.5; total time=   0.3s
# [CV] END ..........svc__C=100, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END ..........svc__C=100, svc__degree=5, svc__gamma=0.5; total time=   0.3s
# [CV] END ..........svc__C=100, svc__degree=5, svc__gamma=0.5; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=5, svc__gamma=0.75; total time=   0.3s
# [CV] END .........svc__C=100, svc__degree=5, svc__gamma=0.75; total time=   0.3s
# [CV] END .........svc__C=100, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END .........svc__C=100, svc__degree=5, svc__gamma=0.75; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=5, svc__gamma=1; total time=   0.2s
# [CV] END ............svc__C=100, svc__degree=5, svc__gamma=1; total time=   0.3s
# [CV] END ............svc__C=100, svc__degree=5, svc__gamma=1; total time=   0.3s
# [CV] END ............svc__C=100, svc__degree=5, svc__gamma=1; total time=   0.6s
# [CV] END ............svc__C=100, svc__degree=5, svc__gamma=1; total time=   0.3s
# 0.8560000000000001

# %% [markdown]
# The polynomial kernel achieved the same accuracy as the linear kernel. What parameter values led to this result?

# %%
grid_search.best_params_
# Out:
# {'svc__C': 0.1, 'svc__degree': 1, 'svc__gamma': 0.01}

# %% [markdown]
# The best_params_ attribute reveals that the optimum value of degree was 1, which means the polynomial kernel acted like a linear kernel. It’s not surprising, then, that it achieved the same accuracy. Could an RBF kernel do better?

# %%
scaler = StandardScaler()
svc = SVC(kernel='rbf')
pipe = make_pipeline(scaler, svc)
 
grid = {
    'svc__C': [0.1, 1, 10, 100],
    'svc__gamma': [0.01, 0.25, 0.5, 0.75, 1.0]
}
 
grid_search = GridSearchCV(estimator=pipe, param_grid=grid, cv=5, verbose=2)
grid_search.fit(x, y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END ........................svc__C=0.1, svc__gamma=0.01; total time=   0.3s
# [CV] END ........................svc__C=0.1, svc__gamma=0.01; total time=   0.3s
# [CV] END ........................svc__C=0.1, svc__gamma=0.01; total time=   0.5s
# [CV] END ........................svc__C=0.1, svc__gamma=0.01; total time=   0.4s
# [CV] END ........................svc__C=0.1, svc__gamma=0.01; total time=   0.4s
# [CV] END ........................svc__C=0.1, svc__gamma=0.25; total time=   0.5s
# [CV] END ........................svc__C=0.1, svc__gamma=0.25; total time=   0.5s
# [CV] END ........................svc__C=0.1, svc__gamma=0.25; total time=   0.6s
# [CV] END ........................svc__C=0.1, svc__gamma=0.25; total time=   0.6s
# [CV] END ........................svc__C=0.1, svc__gamma=0.25; total time=   0.6s
# [CV] END .........................svc__C=0.1, svc__gamma=0.5; total time=   0.5s
# [CV] END .........................svc__C=0.1, svc__gamma=0.5; total time=   0.4s
# [CV] END .........................svc__C=0.1, svc__gamma=0.5; total time=   0.4s
# [CV] END .........................svc__C=0.1, svc__gamma=0.5; total time=   0.5s
# [CV] END .........................svc__C=0.1, svc__gamma=0.5; total time=   0.5s
# [CV] END ........................svc__C=0.1, svc__gamma=0.75; total time=   0.5s
# [CV] END ........................svc__C=0.1, svc__gamma=0.75; total time=   0.3s
# [CV] END ........................svc__C=0.1, svc__gamma=0.75; total time=   0.3s
# [CV] END ........................svc__C=0.1, svc__gamma=0.75; total time=   0.3s
# [CV] END ........................svc__C=0.1, svc__gamma=0.75; total time=   0.3s
# [CV] END .........................svc__C=0.1, svc__gamma=1.0; total time=   0.3s
# [CV] END .........................svc__C=0.1, svc__gamma=1.0; total time=   0.3s
# [CV] END .........................svc__C=0.1, svc__gamma=1.0; total time=   0.3s
# [CV] END .........................svc__C=0.1, svc__gamma=1.0; total time=   0.4s
# [CV] END .........................svc__C=0.1, svc__gamma=1.0; total time=   0.3s
# [CV] END ..........................svc__C=1, svc__gamma=0.01; total time=   0.4s
# [CV] END ..........................svc__C=1, svc__gamma=0.01; total time=   0.3s
# [CV] END ..........................svc__C=1, svc__gamma=0.01; total time=   0.3s
# [CV] END ..........................svc__C=1, svc__gamma=0.01; total time=   0.3s
# [CV] END ..........................svc__C=1, svc__gamma=0.01; total time=   0.3s
# [CV] END ..........................svc__C=1, svc__gamma=0.25; total time=   0.3s
# [CV] END ..........................svc__C=1, svc__gamma=0.25; total time=   0.3s
# [CV] END ..........................svc__C=1, svc__gamma=0.25; total time=   0.3s
# [CV] END ..........................svc__C=1, svc__gamma=0.25; total time=   0.3s
# [CV] END ..........................svc__C=1, svc__gamma=0.25; total time=   0.3s
# [CV] END ...........................svc__C=1, svc__gamma=0.5; total time=   0.3s
# [CV] END ...........................svc__C=1, svc__gamma=0.5; total time=   0.3s
# [CV] END ...........................svc__C=1, svc__gamma=0.5; total time=   0.3s
# [CV] END ...........................svc__C=1, svc__gamma=0.5; total time=   0.3s
# [CV] END ...........................svc__C=1, svc__gamma=0.5; total time=   0.3s
# [CV] END ..........................svc__C=1, svc__gamma=0.75; total time=   0.3s
# [CV] END ..........................svc__C=1, svc__gamma=0.75; total time=   0.3s
# [CV] END ..........................svc__C=1, svc__gamma=0.75; total time=   0.3s
# [CV] END ..........................svc__C=1, svc__gamma=0.75; total time=   0.3s
# [CV] END ..........................svc__C=1, svc__gamma=0.75; total time=   0.3s
# [CV] END ...........................svc__C=1, svc__gamma=1.0; total time=   0.3s
# [CV] END ...........................svc__C=1, svc__gamma=1.0; total time=   0.3s
# [CV] END ...........................svc__C=1, svc__gamma=1.0; total time=   0.3s
# [CV] END ...........................svc__C=1, svc__gamma=1.0; total time=   0.3s
# [CV] END ...........................svc__C=1, svc__gamma=1.0; total time=   0.3s
# [CV] END .........................svc__C=10, svc__gamma=0.01; total time=   0.3s
# [CV] END .........................svc__C=10, svc__gamma=0.01; total time=   0.3s
# [CV] END .........................svc__C=10, svc__gamma=0.01; total time=   0.3s
# [CV] END .........................svc__C=10, svc__gamma=0.01; total time=   0.3s
# [CV] END .........................svc__C=10, svc__gamma=0.01; total time=   0.3s
# [CV] END .........................svc__C=10, svc__gamma=0.25; total time=   0.3s
# [CV] END .........................svc__C=10, svc__gamma=0.25; total time=   0.3s
# [CV] END .........................svc__C=10, svc__gamma=0.25; total time=   0.3s
# [CV] END .........................svc__C=10, svc__gamma=0.25; total time=   0.3s
# [CV] END .........................svc__C=10, svc__gamma=0.25; total time=   0.3s
# [CV] END ..........................svc__C=10, svc__gamma=0.5; total time=   0.3s
# [CV] END ..........................svc__C=10, svc__gamma=0.5; total time=   0.3s
# [CV] END ..........................svc__C=10, svc__gamma=0.5; total time=   0.3s
# [CV] END ..........................svc__C=10, svc__gamma=0.5; total time=   0.4s
# [CV] END ..........................svc__C=10, svc__gamma=0.5; total time=   0.4s
# [CV] END .........................svc__C=10, svc__gamma=0.75; total time=   0.3s
# [CV] END .........................svc__C=10, svc__gamma=0.75; total time=   0.3s
# [CV] END .........................svc__C=10, svc__gamma=0.75; total time=   0.4s
# [CV] END .........................svc__C=10, svc__gamma=0.75; total time=   0.3s
# [CV] END .........................svc__C=10, svc__gamma=0.75; total time=   0.3s
# [CV] END ..........................svc__C=10, svc__gamma=1.0; total time=   0.3s
# [CV] END ..........................svc__C=10, svc__gamma=1.0; total time=   0.3s
# [CV] END ..........................svc__C=10, svc__gamma=1.0; total time=   0.3s
# [CV] END ..........................svc__C=10, svc__gamma=1.0; total time=   0.3s
# [CV] END ..........................svc__C=10, svc__gamma=1.0; total time=   0.3s
# [CV] END ........................svc__C=100, svc__gamma=0.01; total time=   0.3s
# [CV] END ........................svc__C=100, svc__gamma=0.01; total time=   0.3s
# [CV] END ........................svc__C=100, svc__gamma=0.01; total time=   0.3s
# [CV] END ........................svc__C=100, svc__gamma=0.01; total time=   0.3s
# [CV] END ........................svc__C=100, svc__gamma=0.01; total time=   0.3s
# [CV] END ........................svc__C=100, svc__gamma=0.25; total time=   0.3s
# [CV] END ........................svc__C=100, svc__gamma=0.25; total time=   0.3s
# [CV] END ........................svc__C=100, svc__gamma=0.25; total time=   0.3s
# [CV] END ........................svc__C=100, svc__gamma=0.25; total time=   0.3s
# [CV] END ........................svc__C=100, svc__gamma=0.25; total time=   0.3s
# [CV] END .........................svc__C=100, svc__gamma=0.5; total time=   0.3s
# [CV] END .........................svc__C=100, svc__gamma=0.5; total time=   0.3s
# [CV] END .........................svc__C=100, svc__gamma=0.5; total time=   0.3s
# [CV] END .........................svc__C=100, svc__gamma=0.5; total time=   0.3s
# [CV] END .........................svc__C=100, svc__gamma=0.5; total time=   0.3s
# [CV] END ........................svc__C=100, svc__gamma=0.75; total time=   0.3s
# [CV] END ........................svc__C=100, svc__gamma=0.75; total time=   0.3s
# [CV] END ........................svc__C=100, svc__gamma=0.75; total time=   0.3s
# [CV] END ........................svc__C=100, svc__gamma=0.75; total time=   0.3s
# [CV] END ........................svc__C=100, svc__gamma=0.75; total time=   0.3s
# [CV] END .........................svc__C=100, svc__gamma=1.0; total time=   0.3s
# [CV] END .........................svc__C=100, svc__gamma=1.0; total time=   0.3s
# [CV] END .........................svc__C=100, svc__gamma=1.0; total time=   0.3s
# [CV] END .........................svc__C=100, svc__gamma=1.0; total time=   0.3s
# [CV] END .........................svc__C=100, svc__gamma=1.0; total time=   0.3s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                                        ('svc', SVC())]),
#              param_grid={'svc__C': [0.1, 1, 10, 100],
#                          'svc__gamma': [0.01, 0.25, 0.5, 0.75, 1.0]},
#              verbose=2)

# %% [markdown]
# The RBF kernel didn’t perform as well as the linear and polynomial kernels. There’s a lesson here. The RBF kernel often fits to nonlinear data better than other kernels, but it doesn’t always fit better. That’s why the best strategy with an SVM is to try different kernels with different parameter values. The best combination will vary from dataset to dataset. For the LFW dataset, it seems that a linear kernel is best. That’s convenient, because the linear kernel is the fastest of all the kernels Scikit provides.
#
# Confusion matrices are a great way to visualize a model’s accuracy. Let’s split the dataset, train an optimized linear model with 80% of the images, test it with the remaining 20%, and show the results in a confusion matrix.
#
# The first step is to split the dataset. Note the stratify=y parameter, which ensures that the training dataset and the test dataset have the same proportion of samples of each class as the original dataset. In this example, the training dataset will contain 20 samples of each of the five people:

# %%
from sklearn.model_selection import train_test_split
 
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8,
                                                    stratify=y, random_state=0)

# %% [markdown]
# Now train a linear SVM with the optimum C value revealed by the grid search:

# %%
scaler = StandardScaler()
svc = SVC(kernel='linear', C=0.1)
pipe = make_pipeline(scaler, svc)
pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(C=0.1, kernel='linear'))])

# %% [markdown]
# Cross-validate the model to confirm its accuracy:

# %%
from sklearn.model_selection import cross_val_score
 
cross_val_score(pipe, x, y, cv=5).mean()
# Out:
# 0.8560000000000001

# %% [markdown]
# Use a confusion matrix to see how the model performs against the test data:

# %%
from sklearn.metrics import ConfusionMatrixDisplay as cmd

fig, ax = plt.subplots(figsize=(6, 6))
ax.grid(False)
cmd.from_estimator(pipe, x_test, y_test, display_labels=faces.target_names,
                   cmap='Blues', xticks_rotation='vertical', ax=ax)
